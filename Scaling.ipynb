# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
import pymc
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
pc=0.5924
sigma=2.05
mylist11 = []
mylist12 = []

dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/'
base_filename='Problema5'
fig = plt.figure()
ax = fig.add_subplot(111)


pmax_array = np.array([])
i_array = np.array([])


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
for i in range(0,15): 
    id =data.iloc[:,i].idxmax()
    pmax    =data.iloc[id,0]
    fzmax=data.iloc[id,i+1]
    pmax_array = np.append(pmax_array, pmax)
    i_array = np.append(i_array, i)

    
y=np.log10(pc-pmax_array)    
x=np.log10(i_array)

cond = (x>min(x)) & (x<1.1)
xFit = x[ cond ]
yFit = y[ cond ]

x_new = np.linspace(min(xFit),1.1, num=len(xFit)*10)
coefs = poly.polyfit(xFit,yFit , 1)
ffit = poly.polyval(x_new, coefs)
axes = plt.gca()
print (coefs[1])


#z=(9**sigma)*(p-pc)
#z2=(15**sigma)*(p-pc)

ax1=plt.subplot(111)
ax1.scatter(x,y)
ax1.plot(x_new,ffit, linewidth=1,color='k', label=r'$\sigma = %.2f$' %(coefs[1]))
ax1.legend(fontsize=15.,frameon=False)


    
ax1.set_ylabel(r'$log(p_{c}(L)-p_{max})$' )
ax1.set_xlabel('log(s)')
ax1.set_title('Problema5')

plt.savefig('/home/pedro/Escritorio/Problema5.pdf', bbox_inches='tight', rasterized=True, dpi=300)
# Out:
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in log10
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:47: RuntimeWarning: divide by zero encountered in log10
# -0.346998592211

# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
import pymc
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
pc=0.5924
sigma=0.36
mylist11 = []
mylist12 = []

dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/'
base_filename='ScalingNorm'

fig, ax = plt.subplots()

pmax_array = np.array([])
i_array = np.array([])


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
for i in range(41,491): 
    id =data.iloc[:,i].idxmax()
    pmax    =data.iloc[id,0]
    fzmax=data.iloc[id,i]
    p =data.iloc[:,0]
    f =data.iloc[:,i]
    pmax_array = np.append(pmax_array, pmax)
    i_array = np.append(i_array, i)
    z=(i**sigma)*(p-pc)
    #z2=(15**sigma)*(p-pc)
    ax.plot(z,np.log10(f))

    
ax.set_ylabel('log(f(z))' )
ax.set_xlabel('z')
ax.set_title('Problema4')

plt.savefig('/home/pedro/Escritorio/Problema4.pdf', bbox_inches='tight', rasterized=True, dpi=300)
# Out:
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:47: RuntimeWarning: divide by zero encountered in log10
