# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio


dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/'
base_filename='Pinf_L=4'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_4=data.iloc[:,0]
pinf_4=data.iloc[:,1]


base_filename='Pinf_L=8'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_8=data.iloc[:,0]
pinf_8=data.iloc[:,1]

base_filename='Pinf_L=16'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_16=data.iloc[:,0]
pinf_16=data.iloc[:,1]

base_filename='Pinf_L=32'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_32=data.iloc[:,0]
pinf_32=data.iloc[:,1]

base_filename='Pinf_L=64'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_64=data.iloc[:,0]
pinf_64=data.iloc[:,1]

base_filename='Pinf_L=128'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_128=data.iloc[:,0]
pinf_128=data.iloc[:,1]


        

plt.scatter(p_4,pinf_4, label='L=4')
plt.scatter(p_8,pinf_8, label='L=8')
plt.scatter(p_16,pinf_16, label='L=16')
plt.scatter(p_32,pinf_32, label='L=32')
plt.scatter(p_64,pinf_64, label='L=64')
plt.scatter(p_128,pinf_128, label='L=128')
plt.ylabel(r'$p_{\infty}$',fontsize=25.)
plt.xlabel(r'$p$',fontsize=25.)




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Problema2.pdf', bbox_inches='tight', rasterized=True, dpi=300)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio

dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/'
base_filename='dispersionA'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
pc_l=data.iloc[:,0]
l=data.iloc[:,1]  


dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/'
base_filename='Pinf_L=4'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_4=np.log(data.iloc[:,0]-pc_l[0])
pinf_4=np.log(data.iloc[:,1])


cond = (p_4>-3.) 
xFit = p_4[ cond ]
yFit = pinf_4[ cond ]


x_new_max_4 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_4 = poly.polyfit(xFit,yFit , 1)
ffit_max_4 = poly.polyval(x_new_max_4, coefs_max_4)
axes = plt.gca()


base_filename='Pinf_L=8'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_8=np.log(data.iloc[:,0]-pc_l[1])
pinf_8=np.log(data.iloc[:,1])


cond = (p_8>-3.) 
xFit = p_8[ cond ]
yFit = pinf_8[ cond ]


x_new_max_8 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_8 = poly.polyfit(xFit,yFit , 1)
ffit_max_8 = poly.polyval(x_new_max_8, coefs_max_8)
axes = plt.gca()


base_filename='Pinf_L=16'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_16=np.log(data.iloc[:,0]-pc_l[2])
pinf_16=np.log(data.iloc[:,1])

cond = (p_16>-3.) 
xFit = p_16[ cond ]
yFit = pinf_16[ cond ]


x_new_max_16 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_16 = poly.polyfit(xFit,yFit , 1)
ffit_max_16 = poly.polyval(x_new_max_16, coefs_max_16)
axes = plt.gca()



base_filename='Pinf_L=32'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_32=np.log(data.iloc[:,0]-pc_l[3])
pinf_32=np.log(data.iloc[:,1])

cond = (p_32>-3.) 
xFit = p_32[ cond ]
yFit = pinf_32[ cond ]


x_new_max_32 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_32 = poly.polyfit(xFit,yFit , 1)
ffit_max_32 = poly.polyval(x_new_max_32, coefs_max_32)
axes = plt.gca()


base_filename='Pinf_L=64'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_64=np.log(data.iloc[:,0]-pc_l[4])
pinf_64=np.log(data.iloc[:,1])


cond = (p_64>-3.) 
xFit = p_64[ cond ]
yFit = pinf_64[ cond ]


x_new_max_64 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_64 = poly.polyfit(xFit,yFit , 1)
ffit_max_64 = poly.polyval(x_new_max_64, coefs_max_64)
axes = plt.gca()

base_filename='Pinf_L=128'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
p_128=np.log(data.iloc[:,0]-pc_l[5])
pinf_128=np.log(data.iloc[:,1])

cond = (p_128>-3.) 
xFit = p_128[ cond ]
yFit = pinf_128[ cond ]


x_new_max_128 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_128 = poly.polyfit(xFit,yFit , 1)
ffit_max_128 = poly.polyval(x_new_max_128, coefs_max_128)
axes = plt.gca()
      




plt.scatter(p_4,pinf_4, label=r'$\beta(L=4) = %.2f$' %(np.absolute(coefs_max_4[1])))
plt.plot(x_new_max_4,ffit_max_4, linewidth=2)
plt.scatter(p_8,pinf_8,   label=r'$\beta(L=8) = %.2f$' %(np.absolute(coefs_max_8[1])))
plt.plot(x_new_max_8,ffit_max_8, linewidth=2)
plt.scatter(p_16,pinf_16, label=r'$\beta(L=16) = %.2f$' %(np.absolute(coefs_max_16[1])))
plt.plot(x_new_max_16,ffit_max_16, linewidth=2)
plt.scatter(p_32,pinf_32, label=r'$\beta(L=32) = %.2f$' %(np.absolute(coefs_max_32[1])))
plt.plot(x_new_max_32,ffit_max_32, linewidth=2)
plt.scatter(p_64,pinf_64, label=r'$\beta(L=64) = %.2f$' %(np.absolute(coefs_max_64[1])))
plt.plot(x_new_max_64,ffit_max_64, linewidth=2)
plt.scatter(p_128,pinf_128, label=r'$\beta(L=128) = %.2f$' %(np.absolute(coefs_max_128[1])))
plt.plot(x_new_max_128,ffit_max_128, linewidth=2)
plt.ylabel(r'$ln(p_{\infty})$',fontsize=25.)
plt.xlabel(r'$ln(p-p_{c}(L))$',fontsize=25.)




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Problema2log.pdf', bbox_inches='tight', rasterized=True, dpi=300)
# Out:
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in log
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: divide by zero encountered in log
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in log
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: divide by zero encountered in log
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in log
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:86: RuntimeWarning: divide by zero encountered in log
# /home/pedro/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:105: RuntimeWarning: invalid value encountered in log
# ...
