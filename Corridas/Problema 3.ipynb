# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio


dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/'
base_filename='Rho02'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
L02=data.iloc[:,0]
rho02=data.iloc[:,1]


base_filename='Rho001'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
L001=data.iloc[:,0]
rho001=data.iloc[:,1]

base_filename='Rhodp01'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
Ldp01=data.iloc[:,0]
rhodp01=data.iloc[:,1]

base_filename='Rhoinf'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
Linf=data.iloc[:,0]
rhoinf=data.iloc[:,1]



plt.plot(L02,rho02,label=r'$\left |p-p_{c}(L)  \right |=0.02$')
plt.plot(Ldp01,rhodp01,label=r'$\left |p-p_{c}(L)  \right |=0.015$')
plt.plot(L001,rho001,label=r'$\left |p-p_{c}(L)  \right |=0.01$')
plt.plot(Linf,rhoinf,label=r'$\left |p_{c}(L=\infty )-p_{c}(L)  \right |$')


plt.ylabel(r'$\rho$',fontsize=25.)
plt.xlabel(r'$L$',fontsize=25.)




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Problema3.pdf', bbox_inches='tight', rasterized=True, dpi=300)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio


dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/'
base_filename='Rho02'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
L02=np.log(data.iloc[:,0])
rho02=np.log(data.iloc[:,1])

cond = (L02>1.) & (L02<3.5) 
xFit = L02[ cond ]
yFit = rho02[ cond ]


x_new_max_02 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_02 = poly.polyfit(xFit,yFit , 1)
ffit_max_02 = poly.polyval(x_new_max_02, coefs_max_02)
axes = plt.gca()
      

base_filename='Rho001'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
L001=np.log(data.iloc[:,0])
rho001=np.log(data.iloc[:,1])


cond = (L001>1.) & (L001<3.5) 
xFit = L001[ cond ]
yFit = rho001[ cond ]


x_new_max_001 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_001 = poly.polyfit(xFit,yFit , 1)
ffit_max_001 = poly.polyval(x_new_max_001, coefs_max_001)
axes = plt.gca()

base_filename='Rhodp01'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
Ldp01=np.log(data.iloc[:,0])
rhodp01=np.log(data.iloc[:,1])

cond = (Ldp01>1.) & (Ldp01<3.5) 
xFit = Ldp01[ cond ]
yFit = rhodp01[ cond ]


x_new_max_dp01 = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_dp01 = poly.polyfit(xFit,yFit , 1)
ffit_max_dp01 = poly.polyval(x_new_max_dp01, coefs_max_dp01)
axes = plt.gca()

base_filename='Rhoinf'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
Linf=np.log(data.iloc[:,0])
rhoinf=np.log(data.iloc[:,1])

cond = (Linf>1.) & (Linf<3.5) 
xFit = Linf[ cond ]
yFit = rhoinf[ cond ]


x_new_max_inf = np.linspace(min(xFit),max(xFit), num=len(xFit)*10)
coefs_max_inf = poly.polyfit(xFit,yFit , 1)
ffit_max_inf = poly.polyval(x_new_max_inf, coefs_max_inf)
axes = plt.gca()

plt.scatter(L02,rho02,label=r'$D = %.2f$' %(np.absolute(coefs_max_02[1])+2))
plt.plot(x_new_max_02,ffit_max_02, linewidth=2)

plt.scatter(Ldp01,rhodp01,label=r'$D = %.2f$' %(np.absolute(coefs_max_dp01[1])+2))
plt.plot(x_new_max_dp01,ffit_max_dp01, linewidth=2)

plt.scatter(L001,rho001,label=r'$D = %.2f$' %(np.absolute(coefs_max_001[1])+2))
plt.plot(x_new_max_001,ffit_max_001, linewidth=2)

plt.scatter(Linf,rhoinf,label=r'$D = %.2f$' %(np.absolute(coefs_max_inf[1])+2))
plt.plot(x_new_max_inf,ffit_max_inf, linewidth=2)



plt.ylabel(r'$ln(\rho)$',fontsize=25.)
plt.xlabel(r'$ln(L)$',fontsize=25.)




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Problema3log.pdf', bbox_inches='tight', rasterized=True, dpi=300)
