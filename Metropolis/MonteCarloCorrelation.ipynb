# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio


dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/autocorrelacion/'
base_filename='MMCMag_L=34_J=0.100000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t01=data.iloc[:,0]
mag01=data.iloc[:,1]


base_filename='MMCMag_L=34_J=0.200000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t02=data.iloc[:,0]
mag02=data.iloc[:,1]

base_filename='MMCMag_L=34_J=0.300000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t03=data.iloc[:,0]
mag03=data.iloc[:,1]

base_filename='MMCMag_L=34_J=0.400000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t04=data.iloc[:,0]
mag04=data.iloc[:,1]

base_filename='MMCMag_L=34_J=0.500000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t05=data.iloc[:,0]
mag05=data.iloc[:,1]

base_filename='MMCMag_L=34_J=0.600000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t06=data.iloc[:,0]
mag06=data.iloc[:,1]




plt.plot(t01,mag01,label=r'$J=0.1,B=0.0$')
plt.plot(t02,mag02,label=r'$J=0.2,B=0.0$')
plt.plot(t03,mag03,label=r'$J=0.3,B=0.0$')
plt.plot(t04,mag04,label=r'$J=0.4,B=0.0$')
plt.plot(t05,mag05,label=r'$J=0.5,B=0.0$')
plt.plot(t06,mag06,label=r'$J=0.6,B=0.0$')



plt.ylabel(r'$M$',fontsize=25.)
plt.xlabel(r'$t$',fontsize=25.)




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Magnetizacion.pdf', bbox_inches='tight', rasterized=True, dpi=300)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio




dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/autocorrelacion/'
base_filename='MMCMag_L=34_J=0.100000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t01=data.iloc[:,0]
mag01=data.iloc[:,1]

yunbiased = mag01-np.mean(mag01)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor01 = acor[len(acor)/2:]



base_filename='MMCMag_L=34_J=0.200000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t02=data.iloc[:,0]
mag02=data.iloc[:,1]

yunbiased = mag02-np.mean(mag02)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor02 = acor[len(acor)/2:]


base_filename='MMCMag_L=34_J=0.300000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t03=data.iloc[:,0]
mag03=data.iloc[:,1]

yunbiased = mag03-np.mean(mag03)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor03 = acor[len(acor)/2:]


base_filename='MMCMag_L=34_J=0.350000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t035=data.iloc[:,0]
mag035=data.iloc[:,1]

yunbiased = mag035-np.mean(mag035)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor035 = acor[len(acor)/2:]

cond035 = np.where(np.absolute(acor035-0.37)<0.02)[0]

base_filename='MMCMag_L=34_J=0.400000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t04=data.iloc[:,0]
mag04=data.iloc[:,1]

yunbiased = mag04-np.mean(mag04)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor04 = acor[len(acor)/2:]

cond04 = np.where(np.absolute(acor04-0.37)<0.02)[0]



base_filename='MMCMag_L=34_J=0.410000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t041=data.iloc[:,0]
mag041=data.iloc[:,1]

yunbiased = mag041-np.mean(mag041)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor041 = acor[len(acor)/2:]

cond041 = np.where(np.absolute(acor041-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.420000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t042=data.iloc[:,0]
mag042=data.iloc[:,1]

yunbiased = mag042-np.mean(mag042)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor042 = acor[len(acor)/2:]

cond042 = np.where(np.absolute(acor042-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.430000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t043=data.iloc[:,0]
mag043=data.iloc[:,1]

yunbiased = mag043-np.mean(mag043)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor043 = acor[len(acor)/2:]

cond043 = np.where(np.absolute(acor043-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.440000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t044=data.iloc[:,0]
mag044=data.iloc[:,1]

yunbiased = mag044-np.mean(mag044)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor044 = acor[len(acor)/2:]

cond044 = np.where(np.absolute(acor044-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.450000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t045=data.iloc[:,0]
mag045=data.iloc[:,1]

yunbiased = mag045-np.mean(mag045)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor045 = acor[len(acor)/2:]


cond045 = np.where(np.absolute(acor045-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.460000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t046=data.iloc[:,0]
mag046=data.iloc[:,1]

yunbiased = mag046-np.mean(mag046)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor046 = acor[len(acor)/2:]


cond046 = np.where(np.absolute(acor046-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.470000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t047=data.iloc[:,0]
mag047=data.iloc[:,1]

yunbiased = mag047-np.mean(mag047)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor047 = acor[len(acor)/2:]


cond047= np.where(np.absolute(acor047-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.480000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t048=data.iloc[:,0]
mag048=data.iloc[:,1]

yunbiased = mag048-np.mean(mag048)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor048 = acor[len(acor)/2:]


cond048= np.where(np.absolute(acor048-0.37)<0.02)[0]

base_filename='MMCMag_L=34_J=0.490000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t049=data.iloc[:,0]
mag049=data.iloc[:,1]

yunbiased = mag049-np.mean(mag049)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor049 = acor[len(acor)/2:]

cond049 = np.where(np.absolute(acor049-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.500000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t05=data.iloc[:,0]
mag05=data.iloc[:,1]

yunbiased = mag05-np.mean(mag05)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor05 = acor[len(acor)/2:]

cond05 = np.where(np.absolute(acor05-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.550000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t055=data.iloc[:,0]
mag055=data.iloc[:,1]

yunbiased = mag055-np.mean(mag055)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor055 = acor[len(acor)/2:]

cond055 = np.where(np.absolute(acor055-0.37)<0.02)[0]



base_filename='MMCMag_L=34_J=0.600000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t06=data.iloc[:,0]
mag06=data.iloc[:,1]

yunbiased = mag06-np.mean(mag06)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor06 = acor[len(acor)/2:]

cond06 = np.where(np.absolute(acor06-0.37)<0.02)[0]







#plt.plot(acor01,label=r'$J=0.1,B=0.0$')
#plt.plot(acor02,label=r'$J=0.2,B=0.0$')
#plt.plot(acor03,label=r'$J=0.3,B=0.0$')
#plt.plot(acor05,label=r'$J=0.5,B=0.0$')
#plt.plot(acor06,label=r'$J=0.6,B=0.0$')
#plt.plot(acor035,label=r'$J=0.35,B=0.0$')
#plt.plot(acor055,label=r'$J=0.55,B=0.0$')
plt.plot(acor04,label=r'$J=0.4,B=0.0$')
plt.plot(acor041,label=r'$J=0.41,B=0.0$')
plt.plot(acor042,label=r'$J=0.42,B=0.0$')
plt.plot(acor043,label=r'$J=0.43,B=0.0$')
plt.plot(acor044,label=r'$J=0.44,B=0.0$')
plt.plot(acor045,label=r'$J=0.45,B=0.0$')
plt.plot(acor046,label=r'$J=0.46,B=0.0$')
plt.plot(acor047,label=r'$J=0.47,B=0.0$')
plt.plot(acor048,label=r'$J=0.48,B=0.0$')
plt.plot(acor049,label=r'$J=0.49,B=0.0$')




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Magnetizacion.pdf', bbox_inches='tight', rasterized=True, dpi=300)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio




dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/autocorrelacion/'
base_filename='MMCMag_L=34_J=0.100000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t01=data.iloc[:,0]
mag01=data.iloc[:,1]

yunbiased = mag01-np.mean(mag01)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor01 = acor[len(acor)/2:]




base_filename='MMCMag_L=34_J=0.200000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t02=data.iloc[:,0]
mag02=data.iloc[:,1]

yunbiased = mag02-np.mean(mag02)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor02 = acor[len(acor)/2:]


base_filename='MMCMag_L=34_J=0.300000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t03=data.iloc[:,0]
mag03=data.iloc[:,1]

yunbiased = mag03-np.mean(mag03)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor03 = acor[len(acor)/2:]

base_filename='MMCMag_L=34_J=0.400000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t04=data.iloc[:,0]
mag04=data.iloc[:,1]

yunbiased = mag04-np.mean(mag04)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor04 = acor[len(acor)/2:]

cond04 = np.where(np.absolute(acor04-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.500000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t05=data.iloc[:,0]
mag05=data.iloc[:,1]

yunbiased = mag05-np.mean(mag05)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor05 = acor[len(acor)/2:]

cond05 = np.where(np.absolute(acor05-0.37)<0.02)[0]



base_filename='MMCMag_L=34_J=0.600000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t06=data.iloc[:,0]
mag06=data.iloc[:,1]

yunbiased = mag06-np.mean(mag06)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor06 = acor[len(acor)/2:]

cond06 = np.where(np.absolute(acor06-0.37)<0.02)[0]



base_filename='MMCMag_L=34_J=0.350000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t035=data.iloc[:,0]
mag035=data.iloc[:,1]

yunbiased = mag035-np.mean(mag035)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor035 = acor[len(acor)/2:]

cond035 = np.where(np.absolute(acor035-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.550000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t055=data.iloc[:,0]
mag055=data.iloc[:,1]

yunbiased = mag055-np.mean(mag055)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor055 = acor[len(acor)/2:]

cond055 = np.where(np.absolute(acor055-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.490000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t049=data.iloc[:,0]
mag049=data.iloc[:,1]

yunbiased = mag049-np.mean(mag049)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor049 = acor[len(acor)/2:]

cond049 = np.where(np.absolute(acor049-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.410000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t041=data.iloc[:,0]
mag041=data.iloc[:,1]

yunbiased = mag041-np.mean(mag041)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor041 = acor[len(acor)/2:]

cond041 = np.where(np.absolute(acor041-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.420000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t042=data.iloc[:,0]
mag042=data.iloc[:,1]

yunbiased = mag042-np.mean(mag042)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor042 = acor[len(acor)/2:]

cond042 = np.where(np.absolute(acor042-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.430000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t043=data.iloc[:,0]
mag043=data.iloc[:,1]

yunbiased = mag043-np.mean(mag043)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor043 = acor[len(acor)/2:]

cond043 = np.where(np.absolute(acor043-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.440000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t044=data.iloc[:,0]
mag044=data.iloc[:,1]

yunbiased = mag044-np.mean(mag044)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor044 = acor[len(acor)/2:]

cond044 = np.where(np.absolute(acor044-0.37)<0.02)[0]


base_filename='MMCMag_L=34_J=0.450000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t045=data.iloc[:,0]
mag045=data.iloc[:,1]

yunbiased = mag045-np.mean(mag045)
ynorm = np.sum(yunbiased**2)
acor = np.correlate(yunbiased, yunbiased, "same")/ynorm
# use only second half
acor045 = acor[len(acor)/2:]


cond045 = np.where(np.absolute(acor045-0.37)<0.02)[0]


plt.scatter(0.4,cond04[0])
#plt.scatter(0.41,cond041[0])
plt.scatter(0.42,cond042[0])
plt.scatter(0.43,cond043[0])
plt.scatter(0.44,cond044[0])
plt.scatter(0.45,cond045[0])
plt.scatter(0.46,cond046[0])
plt.scatter(0.47,cond047[0])
#plt.scatter(0.48,cond048[0])
plt.scatter(0.49,cond049[0])
plt.scatter(0.5,cond05[0])




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Magnetizacion2.pdf', bbox_inches='tight', rasterized=True, dpi=300)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev
import numpy.polynomial.polynomial as poly
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(15,15)) # Notice the equal aspect ratio


dir_name='/home/pedro/Escritorio/Fisica-Computacional-master/autocorrelacion/'
base_filename='MMCEn_L=34_J=0.100000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t01=data.iloc[:,0]
mag01=data.iloc[:,1]


base_filename='MMCEn_L=34_J=0.200000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t02=data.iloc[:,0]
mag02=data.iloc[:,1]

base_filename='MMCEn_L=34_J=0.300000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t03=data.iloc[:,0]
mag03=data.iloc[:,1]

base_filename='MMCEn_L=34_J=0.400000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t04=data.iloc[:,0]
mag04=data.iloc[:,1]

base_filename='MMCEn_L=34_J=0.500000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t05=data.iloc[:,0]
mag05=data.iloc[:,1]

base_filename='MMCEn_L=34_J=0.600000_B=0.000000'


filename =  os.path.join(dir_name, base_filename + "." + 'dat')
data = pd.read_table(filename, header=None, sep="\s+")
t06=data.iloc[:,0]
mag06=data.iloc[:,1]




plt.plot(t01,mag01,label=r'$J=0.1,B=0.0$')
plt.plot(t02,mag02,label=r'$J=0.2,B=0.0$')
plt.plot(t03,mag03,label=r'$J=0.3,B=0.0$')
plt.plot(t04,mag04,label=r'$J=0.4,B=0.0$')
plt.plot(t05,mag05,label=r'$J=0.5,B=0.0$')
plt.plot(t06,mag06,label=r'$J=0.6,B=0.0$')



plt.ylabel(r'$Energia$',fontsize=25.)
plt.xlabel(r'$t$',fontsize=25.)




plt.legend(fontsize=25.,frameon=False)

plt.savefig('/home/pedro/Escritorio/Fisica-Computacional-master/Corridas/Energia.pdf', bbox_inches='tight', rasterized=True, dpi=300)
