# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy


factor=0.15
factor2=0.866


dim = sum(1 for line in open('/home/pedro/Desktop/Tablas_Python/TablaCompleta.dat'))

Ngr_1=np.zeros((dim,), dtype=np.int)
Ngr_2=np.zeros((dim,), dtype=np.int)
Nsub_1=np.zeros((dim,), dtype=np.int)
Nsub_2=np.zeros((dim,), dtype=np.int)
Mhvir_1=np.zeros((dim,), dtype=np.float)
Mhvir01_1=np.zeros((dim,), dtype=np.float)
Mhvir02_1=np.zeros((dim,), dtype=np.float)
Mhvir03_1=np.zeros((dim,), dtype=np.float)
Msvir_1=np.zeros((dim,), dtype=np.float)
Msvir01_1=np.zeros((dim,), dtype=np.float)
Msvir02_1=np.zeros((dim,), dtype=np.float)
Msvir03_1=np.zeros((dim,), dtype=np.float)
Mgvir_1=np.zeros((dim,), dtype=np.float)
Msrop_1=np.zeros((dim,), dtype=np.float)
Mgrop_1=np.zeros((dim,), dtype=np.float)
rvir_1=np.zeros((dim,), dtype=np.float)
rop_1=np.zeros((dim,), dtype=np.float)
rhm_1=np.zeros((dim,), dtype=np.float)
Mhvir_2=np.zeros((dim,), dtype=np.float)
Mhvir01_2=np.zeros((dim,), dtype=np.float)
Mhvir02_2=np.zeros((dim,), dtype=np.float)
Mhvir03_2=np.zeros((dim,), dtype=np.float)
rvir_2=np.zeros((dim,), dtype=np.float)

DT=np.zeros((dim,), dtype=np.float)

T005=np.zeros((dim,), dtype=np.float)
Q005=np.zeros((dim,), dtype=np.float)
S005=np.zeros((dim,), dtype=np.float)

TRvir=np.zeros((dim,), dtype=np.float)
QRvir=np.zeros((dim,), dtype=np.float)
SRvir=np.zeros((dim,), dtype=np.float)

cosjota_5rvir=np.zeros((dim,), dtype=np.float)
cosjota_gas5rvir=np.zeros((dim,), dtype=np.float)
cosjota_rop=np.zeros((dim,), dtype=np.float)
cosjota_gasop=np.zeros((dim,), dtype=np.float)
cosjota_5rvirbar=np.zeros((dim,), dtype=np.float)

T005DMO=np.zeros((dim,), dtype=np.float)
Q005DMO=np.zeros((dim,), dtype=np.float)
S005DMO=np.zeros((dim,), dtype=np.float)

TRvirDMO=np.zeros((dim,), dtype=np.float)
QRvirDMO=np.zeros((dim,), dtype=np.float)
SRvirDMO=np.zeros((dim,), dtype=np.float)


DT1=np.zeros((dim,), dtype=np.float)
DT2=np.zeros((dim,), dtype=np.float)
DT3=np.zeros((dim,), dtype=np.float)
DT4=np.zeros((dim,), dtype=np.float)
DT5=np.zeros((dim,), dtype=np.float)
DT6=np.zeros((dim,), dtype=np.float)
DT7=np.zeros((dim,), dtype=np.float)
DT8=np.zeros((dim,), dtype=np.float)
DT9=np.zeros((dim,), dtype=np.float)
DT10=np.zeros((dim,), dtype=np.float)
DT11=np.zeros((dim,), dtype=np.float)
DT12=np.zeros((dim,), dtype=np.float)
DT13=np.zeros((dim,), dtype=np.float)
DT14=np.zeros((dim,), dtype=np.float)
DT15=np.zeros((dim,), dtype=np.float)
DT16=np.zeros((dim,), dtype=np.float)
DT17=np.zeros((dim,), dtype=np.float)
DT18=np.zeros((dim,), dtype=np.float)

    
er1=np.zeros((dim,), dtype=np.float)
er2=np.zeros((dim,), dtype=np.float)
er3=np.zeros((dim,), dtype=np.float)
er4=np.zeros((dim,), dtype=np.float)
er5=np.zeros((dim,), dtype=np.float)
er6=np.zeros((dim,), dtype=np.float)
er7=np.zeros((dim,), dtype=np.float)
er8=np.zeros((dim,), dtype=np.float)
er9=np.zeros((dim,), dtype=np.float)
er10=np.zeros((dim,), dtype=np.float)
er11=np.zeros((dim,), dtype=np.float)
er12=np.zeros((dim,), dtype=np.float)
er13=np.zeros((dim,), dtype=np.float)
er14=np.zeros((dim,), dtype=np.float)
er15=np.zeros((dim,), dtype=np.float)
er16=np.zeros((dim,), dtype=np.float)
er17=np.zeros((dim,), dtype=np.float)
er18=np.zeros((dim,), dtype=np.float)
 

cos1=np.zeros((dim,), dtype=np.float)
cos2=np.zeros((dim,), dtype=np.float)
cos3=np.zeros((dim,), dtype=np.float)
cos4=np.zeros((dim,), dtype=np.float)
cos5=np.zeros((dim,), dtype=np.float)
cos6=np.zeros((dim,), dtype=np.float)
cos7=np.zeros((dim,), dtype=np.float)
cos8=np.zeros((dim,), dtype=np.float)
cos9=np.zeros((dim,), dtype=np.float)
cos10=np.zeros((dim,), dtype=np.float)
cos11=np.zeros((dim,), dtype=np.float)
cos12=np.zeros((dim,), dtype=np.float)
cos13=np.zeros((dim,), dtype=np.float)
cos14=np.zeros((dim,), dtype=np.float)
cos15=np.zeros((dim,), dtype=np.float)
cos16=np.zeros((dim,), dtype=np.float)
cos17=np.zeros((dim,), dtype=np.float)
cos18=np.zeros((dim,), dtype=np.float)
 


mylist = []
mylist2 = []
mylist3 = []
mylist4 = []
mylist5 = []
mylist6 = []
mylist7 = []

mylist8 = []
mylist9 = []
mylist10 = []



with open('/home/pedro/Desktop/Tablas_Python/TablaCompleta.dat', 'r') as Gf:
    for line in Gf:
        mylist.append(line)
Gf.close()

for i in range(dim): 
        lista = mylist[i].split()
        Ngr_1[i] = float(lista[0])
        Ngr_2[i] = float(lista[1])
        Nsub_1[i] = float(lista[2])
        Nsub_2[i] = float(lista[3])
        Mhvir_1[i] = float(lista[4])
        Mhvir01_1[i] = float(lista[5])
        Mhvir02_1[i] = float(lista[6])
        Mhvir03_1[i] = float(lista[7])
        Msvir_1[i] = float(lista[8])
        Msvir01_1[i] = float(lista[9])
        Msvir02_1[i] = float(lista[10])
        Msvir03_1[i] = float(lista[11])
        Mgvir_1[i] = float(lista[12])
        Msrop_1[i] = float(lista[13])
        Mgrop_1[i] = float(lista[14])
        rvir_1[i] = float(lista[15])
        rop_1[i] = float(lista[16])
        rhm_1[i] = float(lista[17])
        Mhvir_2[i] = float(lista[18])
        Mhvir01_2[i] = float(lista[19])
        Mhvir02_2[i] = float(lista[20])
        Mhvir03_2[i] = float(lista[21])
        rvir_2[i] = float(lista[22])

with open('/home/pedro/Desktop/Tablas_Python/Bariones_230_z=0.05_4.dat', 'r') as Gf2:
    for line in Gf2:
        mylist2.append(line)
Gf2.close()     
for i in range(dim):
        lista = mylist2[i].split()
        DT[i] = float(lista[5])
        
with open('/home/pedro/Desktop/Tablas_Python/QST_005Rvir.dat', 'r') as Gf3:
    for line in Gf3:
        mylist3.append(line)
Gf3.close()     
for i in range(dim):
        lista = mylist3[i].split()
        T005[i] = float(lista[0])  
        Q005[i] = float(lista[1])  
        S005[i] = float(lista[2]) 
    
with open('/home/pedro/Desktop/Tablas_Python/QST_Rvir.dat', 'r') as Gf4:
    for line in Gf4:
        mylist4.append(line)
Gf4.close()     
for i in range(dim):
        lista = mylist4[i].split()
        TRvir[i] = float(lista[0])  
        QRvir[i] = float(lista[1])  
        SRvir[i] = float(lista[2]) 
        
with open('/home/pedro/Desktop/Tablas_Python/Tablas_cos2.dat', 'r') as Gf5:
    for line in Gf5:
        mylist5.append(line)
Gf5.close()     
for i in range(dim):
        lista = mylist5[i].split()
        cosjota_5rvir[i] = float(lista[2])  
        cosjota_gas5rvir[i] = float(lista[3])  
        cosjota_rop[i] = float(lista[4])  
        cosjota_gasop[i] = float(lista[5])  
        cosjota_5rvirbar[i] = float(lista[6])  
        
with open('/home/pedro/Desktop/Tablas_Python/QST_Dmo005Rvir.dat', 'r') as Gf6:
    for line in Gf6:
        mylist6.append(line)
Gf6.close()     
for i in range(dim):
        lista = mylist6[i].split()
        T005DMO[i] = float(lista[0])  
        Q005DMO[i] = float(lista[1])  
        S005DMO[i] = float(lista[2]) 
 

with open('/home/pedro/Desktop/Tablas_Python/QST_DmoRvir.dat', 'r') as Gf7:
    for line in Gf7:
        mylist7.append(line)
Gf7.close()     
for i in range(dim):
        lista = mylist7[i].split()
        TRvirDMO[i] = float(lista[0])  
        QRvirDMO[i] = float(lista[1])  
        SRvirDMO[i] = float(lista[2])
        
        
with open('/home/pedro/Desktop/Tablas_Python/DTsuavizado.dat', 'r') as Gf8:
    for line in Gf8:
        mylist8.append(line)
Gf8.close()     
for i in range(dim):
        lista = mylist8[i].split()
        DT1[i] = float(lista[0])
        DT2[i] = float(lista[1])
        DT3[i] = float(lista[2])
        DT4[i] = float(lista[3])
        DT5[i] = float(lista[4])
        DT6[i] = float(lista[5])
        DT7[i] = float(lista[6])
        DT8[i] = float(lista[7])
        DT9[i] = float(lista[8])
        DT10[i] = float(lista[9])
        DT11[i] = float(lista[10])
        DT12[i] = float(lista[11])
        DT13[i] = float(lista[12])
        DT14[i] = float(lista[13])
        DT15[i] = float(lista[14])
        DT16[i] = float(lista[15])
        DT17[i] = float(lista[16])
        DT18[i] = float(lista[17])
        
      
with open('/home/pedro/Desktop/Tablas_Python/Ersuavizado.dat', 'r') as Gf9:
    for line in Gf9:
        mylist9.append(line)
Gf9.close()     
for i in range(dim):
        lista = mylist9[i].split()
        er1[i] = float(lista[0])
        er2[i] = float(lista[1])
        er3[i] = float(lista[2])
        er4[i] = float(lista[3])
        er5[i] = float(lista[4])
        er6[i] = float(lista[5])
        er7[i] = float(lista[6])
        er8[i] = float(lista[7])
        er9[i] = float(lista[8])
        er10[i] = float(lista[9])
        er11[i] = float(lista[10])
        er12[i] = float(lista[11])
        er13[i] = float(lista[12])
        er14[i] = float(lista[13])
        er15[i] = float(lista[14])
        er16[i] = float(lista[15])
        er17[i] = float(lista[16])
        er18[i] = float(lista[17])
        
with open('/home/pedro/Desktop/Tablas_Python/COSsuavizado.dat', 'r') as Gf10:
    for line in Gf10:
        mylist10.append(line)
Gf10.close()     
for i in range(dim):
        lista = mylist10[i].split()
        cos1[i] = float(lista[0])
        cos2[i] = float(lista[1])
        cos3[i] = float(lista[2])
        cos4[i] = float(lista[3])
        cos5[i] = float(lista[4])
        cos6[i] = float(lista[5])
        cos7[i] = float(lista[6])
        cos8[i] = float(lista[7])
        cos9[i] = float(lista[8])
        cos10[i] = float(lista[9])
        cos11[i] = float(lista[10])
        cos12[i] = float(lista[11])
        cos13[i] = float(lista[12])
        cos14[i] = float(lista[13])
        cos15[i] = float(lista[14])
        cos16[i] = float(lista[15])
        cos17[i] = float(lista[16])
        cos18[i] = float(lista[17])    
        
  
        
index  = np.where((Nsub_1 != 917) & (Nsub_1 != 637)) 
index0  = np.where((Nsub_1 == 917))
index1  = np.where((Nsub_1 == 637))

er=rhm_1*100/rvir_1

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
import pymc
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev



mylist11 = []
mylist12 = []


rHydro=np.zeros((100,), dtype=np.float)
QHydro=np.zeros((100,), dtype=np.float)
SHydro=np.zeros((100,), dtype=np.float)
THydro=np.zeros((100,), dtype=np.float)


rDMO=np.zeros((100,), dtype=np.float)
QDMO=np.zeros((100,), dtype=np.float)
SDMO=np.zeros((100,), dtype=np.float)
TDMO=np.zeros((100,), dtype=np.float)


x=np.log10(Mhvir_1)
y=Q005
z=Q005DMO
bin_size=0.5

#define a moving average function
def moving_average(x,y,z,step_size=(np.max(x)-np.min(x))/28):
    bin_centers  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg = np.zeros(len(bin_centers))

    for index in range(0,len(bin_centers)):
        bin_center = bin_centers[index]
        items_in_bin = y[(x>(bin_center-z*0.5) ) & (x<(bin_center+z*0.5))]
        bin_avg[index] = np.mean(items_in_bin)

    return bin_centers,bin_avg

def moving_percentile75(x,y,z,step_size=(np.max(x)-np.min(x))/28):
    bin_centers75  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg75 = np.zeros(len(bin_centers75))

    for index in range(0,len(bin_centers75)):
        bin_center75 = bin_centers75[index]
        items_in_bin = y[(x>(bin_center75-z*0.5) ) & (x<(bin_center75+z*0.5))]
        bin_avg75[index] = np.percentile(items_in_bin,75)

    return bin_centers75,bin_avg75


def moving_percentile25(x,y,z,step_size=(np.max(x)-np.min(x))/28):
    bin_centers25  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg25 = np.zeros(len(bin_centers25))

    for index in range(0,len(bin_centers25)):
        bin_center25 = bin_centers25[index]
        items_in_bin = y[(x>(bin_center25-z*0.5) ) & (x<(bin_center25+z*0.5))]
        bin_avg25[index] = np.percentile(items_in_bin,25)

    return bin_centers25,bin_avg25

def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth


plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(8,20)) # Notice the equal aspect ratio


# equivalent but more general
ax1=plt.subplot(3,1, 1)#, gridspec_kw={"width_ratios":1})
ax2=plt.subplot(3,1, 2)#, gridspec_kw={"width_ratios":1}) 
ax3=plt.subplot(3,1, 3)#, gridspec_kw={"width_ratios":1}) 


fig.subplots_adjust(wspace=0, hspace=0.05)
ax1.set_xlim(0.05,1.)
ax1.set_ylim(0.5,1.)
ax2.set_xlim(0.05,1.)
ax2.set_ylim(0.4,1.)
ax3.set_xlim(0.05,0.98)
ax3.set_ylim(0.0,1.1)
ax1.tick_params(which="both",direction='in', bottom="on", top="on", left="on", right="on")
ax2.tick_params(which="both",direction='in', bottom="on", top="on", left="on", right="on")
ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])
ax1.set_ylabel('$q$',fontsize=40)
ax2.set_ylabel('$s$',fontsize=40)
ax3.set_ylabel('$T$',fontsize=40)
ax3.set_xlabel('r/R$_{\mathrm{200}}$',fontsize=30)

ax1.set_xscale('log')
ax2.set_xscale('log')
ax3.set_xscale('log')
tick_spacing = 0.2

ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax1.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax2.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax2.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax2.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax3.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax3.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax3.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])


appended_data = []
appended_dataDMO = []


for i in range(dim):
    if (np.log10(Mhvir_1[i])> 12.) :
        folder_path = '/home/pedro/Desktop/Tablas_Python/shape/shapeHydro/'
        for filename in glob.glob(os.path.join(folder_path,'axis'+'_'+'XXXX'+str(Ngr_1[i])+'_' + str(Nsub_1[i])+'.dat')):
            data = pd.read_table(filename, header=None, sep="\s+")
            data = data[data.iloc[:,1].between(0.05, 1., inclusive=True)]
            rHydro        =data.iloc[:,0]
            QHydro        =data.iloc[:,1]
            SHydro        = data.iloc[:,2]
            #THydro = (1-(QHydro )^2)/(1-(SHydro)^2)
            appended_data.append(data)
            x=rHydro/rvir_1[i]
            y=QHydro
            z=SHydro
            w=(1-(QHydro )**2)/(1-(SHydro)**2)
            bin_size=0.05
            binsQ, averageQ = moving_average(x,y,bin_size)
            binsS, averageS = moving_average(x,z,bin_size) 
            binsT, averageT = moving_average(x,w,bin_size)
            #ax1.plot(x, y, linewidth=1.,ls='-',label='_nolegend_')
            #ax1.plot(binsQ, averageQ, linewidth=0.5,label='_nolegend_')
            #ax2.plot(x, z, linewidth=1.,ls='-',label='_nolegend_'  )
            #ax2.plot(binsS, averageS, linewidth=0.5,label='_nolegend_')  
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            data.iloc[:,0] = data.iloc[:,0]/rvir_1[i]
            
        folder_path = '/home/pedro/Desktop/Tablas_Python/shape/shapeDMOcorr/'
        for filename in glob.glob(os.path.join(folder_path,'axis'+'_'+'XXXX'+str(Ngr_2[i])+'_' + str(Nsub_2[i])+'.dat')):
            dataDMO = pd.read_table(filename, header=None, sep="\s+")
            dataDMO = dataDMO[dataDMO.iloc[:,1].between(0.05, 1., inclusive=True)]
            rDMO        =dataDMO.iloc[:,0]
            QDMO        =dataDMO.iloc[:,1]
            SDMO        =dataDMO.iloc[:,2]
            appended_dataDMO.append(dataDMO)
            x=rDMO/rvir_2[i]
            y=QDMO
            z=SDMO
            w=(1-(QDMO)**2)/(1-(SDMO)**2)
            bin_size=0.05
            binsQDMO, averageQDMO = moving_average(x,y,bin_size)
            binsSDMO, averageSDMO = moving_average(x,z,bin_size) 
            binsTDMO, averageTDMO = moving_average(x,w,bin_size)
            #ax1.plot(x, y, linewidth=1.,ls='-',label='_nolegend_' , color='k')
            #ax1.plot(binsQDMO, averageQDMO, linewidth=0.5,label='_nolegend_', color='k')
            #ax2.plot(x, z, linewidth=1.,ls='-',label='_nolegend_', color='k')
            #ax2.plot(binsSDMO, averageSDMO, linewidth=0.5,label='_nolegend_', color='k')
            #ax3.plot(x, w, linewidth=1.,ls='-',label='_nolegend_' , color='k')
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            dataDMO.iloc[:,0] = dataDMO.iloc[:,0]/rvir_2[i]   

        df= pd.concat(appended_data, ignore_index=True, axis=0).drop_duplicates().reset_index(drop=True)
        dfDMO= pd.concat(appended_dataDMO, ignore_index=True, axis=0).drop_duplicates().reset_index(drop=True)  
rHydro_pro=df.iloc[:,0]
QHydro_pro=df.iloc[:,1]
SHydro_pro=df.iloc[:,2]

rDMO_pro=dfDMO.iloc[:,0]
QDMO_pro=dfDMO.iloc[:,1]
SDMO_pro=dfDMO.iloc[:,2]

ord = np.argsort(rHydro_pro)
rHydro_pro_ord =rHydro_pro[ord]
QHydro_pro_ord =QHydro_pro[ord]
SHydro_pro_ord =SHydro_pro[ord]


ordDMO = np.argsort(rDMO_pro)
rDMO_pro_ord =rDMO_pro[ordDMO]
QDMO_pro_ord =QDMO_pro[ordDMO]
SDMO_pro_ord =SDMO_pro[ordDMO]


x=rHydro_pro_ord
y=QHydro_pro_ord

bin_size=0.05

binsQ, averageQ = moving_average(x,y,bin_size)
bins75Q, p75Q   = moving_percentile75(x,y,bin_size)
bins25Q, p25Q   = moving_percentile25(x,y,bin_size)

x=rHydro_pro_ord
z=SHydro_pro_ord
bin_size=0.05

binsS, averageS = moving_average(x,z,bin_size)
bins75S, p75S   = moving_percentile75(x,z,bin_size)
bins25S, p25S   = moving_percentile25(x,z,bin_size)

x=rHydro_pro_ord
z=(1-(QHydro_pro_ord)**2)/(1-(SHydro_pro_ord)**2)
bin_size=0.05

binsT, averageT = moving_average(x,z,bin_size)
bins75T, p75T   = moving_percentile75(x,z,bin_size)
bins25T, p25T   = moving_percentile25(x,z,bin_size)

x=rDMO_pro_ord
y=QDMO_pro_ord

bin_size=0.05

binsQDMO, averageQDMO = moving_average(x,y,bin_size)
bins75QDMO, p75QDMO = moving_percentile75(x,y,bin_size)
bins25QDMO, p25QDMO = moving_percentile25(x,y,bin_size)


x=rDMO_pro_ord
z=SDMO_pro_ord
bin_size=0.08

binsSDMO, averageSDMO = moving_average(x,z,bin_size)
bins75SDMO, p75SDMO = moving_percentile75(x,z,bin_size)
bins25SDMO, p25SDMO = moving_percentile25(x,z,bin_size)

x=rDMO_pro_ord
z=(1-(QDMO_pro_ord)**2)/(1-(SDMO_pro_ord)**2)
bin_size=0.05

binsTDMO, averageTDMO = moving_average(x,z,bin_size)
bins75TDMO, p75TDMO = moving_percentile75(x,z,bin_size)
bins25TDMO, p25TDMO = moving_percentile25(x,z,bin_size)



ax1.plot(binsQ, averageQ, linewidth=5.,color='r' )
ax1.fill_between(binsQ, p75Q, p25Q,facecolor='grey', alpha=0.5,color='r')
ax1.plot(binsQDMO, averageQDMO, linewidth=5.,label='gola',color='k' )
ax1.fill_between(binsQDMO, p75QDMO, p25QDMO,facecolor='grey', alpha=0.5,color='k')

ax2.plot(binsS, averageS, linewidth=5.,color='r')
ax2.fill_between(binsS, p75S, p25S, alpha=0.5,color='r')
ax2.plot(binsSDMO, averageSDMO, linewidth=5.,color='k')
ax2.fill_between(binsSDMO, p75SDMO, p25SDMO, alpha=0.5,color='k')

ax3.plot(binsT, averageT, linewidth=5.,color='r')
ax3.fill_between(binsT, p75T, p25T, alpha=0.5,color='r')
ax3.plot(binsTDMO, averageTDMO, linewidth=5.,color='k')
ax3.fill_between(binsTDMO, p75TDMO, p25TDMO, alpha=0.5,color='k')



empty_patch = mpatches.Patch(color='none', label=r'$10^{13.0-12.0}M_{\odot }$') 
ax3.legend(handles=[empty_patch],fontsize=20.)



plt.savefig('/home/pedro/Desktop/Imagenes_Python/Promediados/Formas/PromediadoQSTHydro-DMOM1.pdf', bbox_inches='tight', rasterized=True, dpi=300) ### for publication

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
import pymc
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev



mylist11 = []
mylist12 = []


rHydro=np.zeros((100,), dtype=np.float)
QHydro=np.zeros((100,), dtype=np.float)
SHydro=np.zeros((100,), dtype=np.float)
THydro=np.zeros((100,), dtype=np.float)


rDMO=np.zeros((100,), dtype=np.float)
QDMO=np.zeros((100,), dtype=np.float)
SDMO=np.zeros((100,), dtype=np.float)
TDMO=np.zeros((100,), dtype=np.float)


x=np.log10(Mhvir_1)
y=Q005
z=Q005DMO
bin_size=0.5

#define a moving average function
def moving_average(x,y,z,step_size=(np.max(x)-np.min(x))/35):
    bin_centers  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg = np.zeros(len(bin_centers))

    for index in range(0,len(bin_centers)):
        bin_center = bin_centers[index]
        items_in_bin = y[(x>(bin_center-z*0.5) ) & (x<(bin_center+z*0.5))]
        bin_avg[index] = np.mean(items_in_bin)

    return bin_centers,bin_avg

def moving_percentile75(x,y,z,step_size=(np.max(x)-np.min(x))/35):
    bin_centers75  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg75 = np.zeros(len(bin_centers75))

    for index in range(0,len(bin_centers75)):
        bin_center75 = bin_centers75[index]
        items_in_bin = y[(x>(bin_center75-z*0.5) ) & (x<(bin_center75+z*0.5))]
        bin_avg75[index] = np.percentile(items_in_bin,75)

    return bin_centers75,bin_avg75


def moving_percentile25(x,y,z,step_size=(np.max(x)-np.min(x))/35):
    bin_centers25  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg25 = np.zeros(len(bin_centers25))

    for index in range(0,len(bin_centers25)):
        bin_center25 = bin_centers25[index]
        items_in_bin = y[(x>(bin_center25-z*0.5) ) & (x<(bin_center25+z*0.5))]
        bin_avg25[index] = np.percentile(items_in_bin,25)

    return bin_centers25,bin_avg25

def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth


plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(8,20)) # Notice the equal aspect ratio


# equivalent but more general
ax1=plt.subplot(3,1, 1)#, gridspec_kw={"width_ratios":1})
ax2=plt.subplot(3,1, 2)#, gridspec_kw={"width_ratios":1}) 
ax3=plt.subplot(3,1, 3)#, gridspec_kw={"width_ratios":1}) 


fig.subplots_adjust(wspace=0, hspace=0.05)
ax1.set_xlim(0.05,1.)
ax1.set_ylim(0.5,1.)
ax2.set_xlim(0.05,1.)
ax2.set_ylim(0.4,1.)
ax3.set_xlim(0.05,0.98)
ax3.set_ylim(0.0,1.1)
ax1.tick_params(which="both",direction='in', bottom="on", top="on", left="on", right="on")
ax2.tick_params(which="both",direction='in', bottom="on", top="on", left="on", right="on")
ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])
ax1.set_ylabel('$q$',fontsize=40)
ax2.set_ylabel('$s$',fontsize=40)
ax3.set_ylabel('$T$',fontsize=40)
ax3.set_xlabel('r/R$_{\mathrm{200}}$',fontsize=30)

ax1.set_xscale('log')
ax2.set_xscale('log')
ax3.set_xscale('log')
tick_spacing = 0.2

ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax1.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax2.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax2.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax2.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax3.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax3.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax3.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])


appended_data = []
appended_dataDMO = []


for i in range(dim):
    if (np.log10(Mhvir_1[i])< 12.) & (np.log10(Mhvir_1[i]) > 11.5) :
        folder_path = '/home/pedro/Desktop/Tablas_Python/shape/shapeHydro/'
        for filename in glob.glob(os.path.join(folder_path,'axis'+'_'+'XXXX'+str(Ngr_1[i])+'_' + str(Nsub_1[i])+'.dat')):
            data = pd.read_table(filename, header=None, sep="\s+")
            data = data[data.iloc[:,1].between(0.05, 1., inclusive=True)]
            rHydro        =data.iloc[:,0]
            QHydro        =data.iloc[:,1]
            SHydro        = data.iloc[:,2]
            #THydro = (1-(QHydro )^2)/(1-(SHydro)^2)
            appended_data.append(data)
            x=rHydro/rvir_1[i]
            y=QHydro
            z=SHydro
            w=(1-(QHydro )**2)/(1-(SHydro)**2)
            bin_size=0.05
            binsQ, averageQ = moving_average(x,y,bin_size)
            binsS, averageS = moving_average(x,z,bin_size) 
            binsT, averageT = moving_average(x,w,bin_size)
            #ax1.plot(x, y, linewidth=1.,ls='-',label='_nolegend_')
            #ax1.plot(binsQ, averageQ, linewidth=0.5,label='_nolegend_')
            #ax2.plot(x, z, linewidth=1.,ls='-',label='_nolegend_'  )
            #ax2.plot(binsS, averageS, linewidth=0.5,label='_nolegend_')  
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            data.iloc[:,0] = data.iloc[:,0]/rvir_1[i]
            
        folder_path = '/home/pedro/Desktop/Tablas_Python/shape/shapeDMOcorr/'
        for filename in glob.glob(os.path.join(folder_path,'axis'+'_'+'XXXX'+str(Ngr_2[i])+'_' + str(Nsub_2[i])+'.dat')):
            dataDMO = pd.read_table(filename, header=None, sep="\s+")
            dataDMO = dataDMO[dataDMO.iloc[:,1].between(0.05, 1., inclusive=True)]
            rDMO        =dataDMO.iloc[:,0]
            QDMO        =dataDMO.iloc[:,1]
            SDMO        =dataDMO.iloc[:,2]
            appended_dataDMO.append(dataDMO)
            x=rDMO/rvir_2[i]
            y=QDMO
            z=SDMO
            w=(1-(QDMO)**2)/(1-(SDMO)**2)
            bin_size=0.05
            binsQDMO, averageQDMO = moving_average(x,y,bin_size)
            binsSDMO, averageSDMO = moving_average(x,z,bin_size) 
            binsTDMO, averageTDMO = moving_average(x,w,bin_size)
            #ax1.plot(x, y, linewidth=1.,ls='-',label='_nolegend_' , color='k')
            #ax1.plot(binsQDMO, averageQDMO, linewidth=0.5,label='_nolegend_', color='k')
            #ax2.plot(x, z, linewidth=1.,ls='-',label='_nolegend_', color='k')
            #ax2.plot(binsSDMO, averageSDMO, linewidth=0.5,label='_nolegend_', color='k')
            #ax3.plot(x, w, linewidth=1.,ls='-',label='_nolegend_' , color='k')
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            dataDMO.iloc[:,0] = dataDMO.iloc[:,0]/rvir_2[i]   

        df= pd.concat(appended_data, ignore_index=True, axis=0).drop_duplicates().reset_index(drop=True)
        dfDMO= pd.concat(appended_dataDMO, ignore_index=True, axis=0).drop_duplicates().reset_index(drop=True)  
rHydro_pro=df.iloc[:,0]
QHydro_pro=df.iloc[:,1]
SHydro_pro=df.iloc[:,2]

rDMO_pro=dfDMO.iloc[:,0]
QDMO_pro=dfDMO.iloc[:,1]
SDMO_pro=dfDMO.iloc[:,2]

ord = np.argsort(rHydro_pro)
rHydro_pro_ord =rHydro_pro[ord]
QHydro_pro_ord =QHydro_pro[ord]
SHydro_pro_ord =SHydro_pro[ord]


ordDMO = np.argsort(rDMO_pro)
rDMO_pro_ord =rDMO_pro[ordDMO]
QDMO_pro_ord =QDMO_pro[ordDMO]
SDMO_pro_ord =SDMO_pro[ordDMO]


x=rHydro_pro_ord
y=QHydro_pro_ord

bin_size=0.05

binsQ, averageQ = moving_average(x,y,bin_size)
bins75Q, p75Q   = moving_percentile75(x,y,bin_size)
bins25Q, p25Q   = moving_percentile25(x,y,bin_size)

x=rHydro_pro_ord
z=SHydro_pro_ord
bin_size=0.05

binsS, averageS = moving_average(x,z,bin_size)
bins75S, p75S   = moving_percentile75(x,z,bin_size)
bins25S, p25S   = moving_percentile25(x,z,bin_size)

x=rHydro_pro_ord
z=(1-(QHydro_pro_ord)**2)/(1-(SHydro_pro_ord)**2)
bin_size=0.05

binsT, averageT = moving_average(x,z,bin_size)
bins75T, p75T   = moving_percentile75(x,z,bin_size)
bins25T, p25T   = moving_percentile25(x,z,bin_size)

x=rDMO_pro_ord
y=QDMO_pro_ord

bin_size=0.05

binsQDMO, averageQDMO = moving_average(x,y,bin_size)
bins75QDMO, p75QDMO = moving_percentile75(x,y,bin_size)
bins25QDMO, p25QDMO = moving_percentile25(x,y,bin_size)


x=rDMO_pro_ord
z=SDMO_pro_ord
bin_size=0.05

binsSDMO, averageSDMO = moving_average(x,z,bin_size)
bins75SDMO, p75SDMO = moving_percentile75(x,z,bin_size)
bins25SDMO, p25SDMO = moving_percentile25(x,z,bin_size)

x=rDMO_pro_ord
z=(1-(QDMO_pro_ord)**2)/(1-(SDMO_pro_ord)**2)
bin_size=0.05

binsTDMO, averageTDMO = moving_average(x,z,bin_size)
bins75TDMO, p75TDMO = moving_percentile75(x,z,bin_size)
bins25TDMO, p25TDMO = moving_percentile25(x,z,bin_size)



ax1.plot(binsQ, averageQ, linewidth=5.,color='r' )
ax1.fill_between(binsQ, p75Q, p25Q,facecolor='grey', alpha=0.5,color='r')
ax1.plot(binsQDMO, averageQDMO, linewidth=5.,label='gola',color='k' )
ax1.fill_between(binsQDMO, p75QDMO, p25QDMO,facecolor='grey', alpha=0.5,color='k')

ax2.plot(binsS, averageS, linewidth=5.,color='r')
ax2.fill_between(binsS, p75S, p25S, alpha=0.5,color='r')
ax2.plot(binsSDMO, averageSDMO, linewidth=5.,color='k')
ax2.fill_between(binsSDMO, p75SDMO, p25SDMO, alpha=0.5,color='k')

ax3.plot(binsT, averageT, linewidth=5.,color='r')
ax3.fill_between(binsT, p75T, p25T, alpha=0.5,color='r')
ax3.plot(binsTDMO, averageTDMO, linewidth=5.,color='k')
ax3.fill_between(binsTDMO, p75TDMO, p25TDMO, alpha=0.5,color='k')



empty_patch = mpatches.Patch(color='none', label=r'$10^{12.0-11.5}M_{\odot }$') 
ax3.legend(handles=[empty_patch],fontsize=20.)



plt.savefig('/home/pedro/Desktop/Imagenes_Python/Promediados/Formas/PromediadoQSTHydro-DMOM2.pdf', bbox_inches='tight', rasterized=True, dpi=300) ### for publication

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import ascii
import matplotlib.colors as colors
from matplotlib import *
import sys
from pylab import *
from matplotlib.colors import LogNorm
import scipy.integrate as integrate
import scipy
import pymc
from astropy.io import fits
import math
import os,glob
import matplotlib.patches as mpatches
from scipy.interpolate import splrep, splev



mylist11 = []
mylist12 = []


rHydro=np.zeros((100,), dtype=np.float)
QHydro=np.zeros((100,), dtype=np.float)
SHydro=np.zeros((100,), dtype=np.float)
THydro=np.zeros((100,), dtype=np.float)


rDMO=np.zeros((100,), dtype=np.float)
QDMO=np.zeros((100,), dtype=np.float)
SDMO=np.zeros((100,), dtype=np.float)
TDMO=np.zeros((100,), dtype=np.float)


x=np.log10(Mhvir_1)
y=Q005
z=Q005DMO
bin_size=0.5

#define a moving average function
def moving_average(x,y,z,step_size=(np.max(x)-np.min(x))/35):
    bin_centers  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg = np.zeros(len(bin_centers))

    for index in range(0,len(bin_centers)):
        bin_center = bin_centers[index]
        items_in_bin = y[(x>(bin_center-z*0.5) ) & (x<(bin_center+z*0.5))]
        bin_avg[index] = np.mean(items_in_bin)

    return bin_centers,bin_avg

def moving_percentile75(x,y,z,step_size=(np.max(x)-np.min(x))/35):
    bin_centers75  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg75 = np.zeros(len(bin_centers75))

    for index in range(0,len(bin_centers75)):
        bin_center75 = bin_centers75[index]
        items_in_bin = y[(x>(bin_center75-z*0.5) ) & (x<(bin_center75+z*0.5))]
        bin_avg75[index] = np.percentile(items_in_bin,75)

    return bin_centers75,bin_avg75


def moving_percentile25(x,y,z,step_size=(np.max(x)-np.min(x))/35):
    bin_centers25  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg25 = np.zeros(len(bin_centers25))

    for index in range(0,len(bin_centers25)):
        bin_center25 = bin_centers25[index]
        items_in_bin = y[(x>(bin_center25-z*0.5) ) & (x<(bin_center25+z*0.5))]
        bin_avg25[index] = np.percentile(items_in_bin,25)

    return bin_centers25,bin_avg25

def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth


plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
#mpl.rcParams['font.size'] = 13
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13
#mpl.rcParams['axes.labelsize'] = 18

fig = plt.figure(figsize=(8,20)) # Notice the equal aspect ratio


# equivalent but more general
ax1=plt.subplot(3,1, 1)#, gridspec_kw={"width_ratios":1})
ax2=plt.subplot(3,1, 2)#, gridspec_kw={"width_ratios":1}) 
ax3=plt.subplot(3,1, 3)#, gridspec_kw={"width_ratios":1}) 


fig.subplots_adjust(wspace=0, hspace=0.05)
ax1.set_xlim(0.05,1.)
ax1.set_ylim(0.5,1.)
ax2.set_xlim(0.05,1.)
ax2.set_ylim(0.4,1.)
ax3.set_xlim(0.05,0.98)
ax3.set_ylim(0.0,1.1)
ax1.tick_params(which="both",direction='in', bottom="on", top="on", left="on", right="on")
ax2.tick_params(which="both",direction='in', bottom="on", top="on", left="on", right="on")
ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])
ax1.set_ylabel('$q$',fontsize=40)
ax2.set_ylabel('$s$',fontsize=40)
ax3.set_ylabel('$T$',fontsize=40)
ax3.set_xlabel('r/R$_{\mathrm{200}}$',fontsize=30)

ax1.set_xscale('log')
ax2.set_xscale('log')
ax3.set_xscale('log')
tick_spacing = 0.2

ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax1.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax2.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax2.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax2.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax3.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax3.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax3.get_xaxis().set_minor_formatter(matplotlib.ticker.NullFormatter())

ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])


appended_data = []
appended_dataDMO = []


for i in range(dim):
    if (np.log10(Mhvir_1[i])< 11.5):
        folder_path = '/home/pedro/Desktop/Tablas_Python/shape/shapeHydro/'
        for filename in glob.glob(os.path.join(folder_path,'axis'+'_'+'XXXX'+str(Ngr_1[i])+'_' + str(Nsub_1[i])+'.dat')):
            data = pd.read_table(filename, header=None, sep="\s+")
            data = data[data.iloc[:,1].between(0.05, 1., inclusive=True)]
            rHydro        =data.iloc[:,0]
            QHydro        =data.iloc[:,1]
            SHydro        = data.iloc[:,2]
            #THydro = (1-(QHydro )^2)/(1-(SHydro)^2)
            appended_data.append(data)
            x=rHydro/rvir_1[i]
            y=QHydro
            z=SHydro
            w=(1-(QHydro )**2)/(1-(SHydro)**2)
            bin_size=0.05
            binsQ, averageQ = moving_average(x,y,bin_size)
            binsS, averageS = moving_average(x,z,bin_size) 
            binsT, averageT = moving_average(x,w,bin_size)
            #ax1.plot(x, y, linewidth=1.,ls='-',label='_nolegend_')
            #ax1.plot(binsQ, averageQ, linewidth=0.5,label='_nolegend_')
            #ax2.plot(x, z, linewidth=1.,ls='-',label='_nolegend_'  )
            #ax2.plot(binsS, averageS, linewidth=0.5,label='_nolegend_')  
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            data.iloc[:,0] = data.iloc[:,0]/rvir_1[i]
            
        folder_path = '/home/pedro/Desktop/Tablas_Python/shape/shapeDMOcorr/'
        for filename in glob.glob(os.path.join(folder_path,'axis'+'_'+'XXXX'+str(Ngr_2[i])+'_' + str(Nsub_2[i])+'.dat')):
            dataDMO = pd.read_table(filename, header=None, sep="\s+")
            dataDMO = dataDMO[dataDMO.iloc[:,1].between(0.05, 1., inclusive=True)]
            rDMO        =dataDMO.iloc[:,0]
            QDMO        =dataDMO.iloc[:,1]
            SDMO        =dataDMO.iloc[:,2]
            appended_dataDMO.append(dataDMO)
            x=rDMO/rvir_2[i]
            y=QDMO
            z=SDMO
            w=(1-(QDMO)**2)/(1-(SDMO)**2)
            bin_size=0.05
            binsQDMO, averageQDMO = moving_average(x,y,bin_size)
            binsSDMO, averageSDMO = moving_average(x,z,bin_size) 
            binsTDMO, averageTDMO = moving_average(x,w,bin_size)
            #ax1.plot(x, y, linewidth=1.,ls='-',label='_nolegend_' , color='k')
            #ax1.plot(binsQDMO, averageQDMO, linewidth=0.5,label='_nolegend_', color='k')
            #ax2.plot(x, z, linewidth=1.,ls='-',label='_nolegend_', color='k')
            #ax2.plot(binsSDMO, averageSDMO, linewidth=0.5,label='_nolegend_', color='k')
            #ax3.plot(x, w, linewidth=1.,ls='-',label='_nolegend_' , color='k')
            #ax3.plot(x, smooth(w,3), linewidth=1.,ls='-',label='_nolegend_'  )
            dataDMO.iloc[:,0] = dataDMO.iloc[:,0]/rvir_2[i]   

        df= pd.concat(appended_data, ignore_index=True, axis=0).drop_duplicates().reset_index(drop=True)
        dfDMO= pd.concat(appended_dataDMO, ignore_index=True, axis=0).drop_duplicates().reset_index(drop=True)  
rHydro_pro=df.iloc[:,0]
QHydro_pro=df.iloc[:,1]
SHydro_pro=df.iloc[:,2]

rDMO_pro=dfDMO.iloc[:,0]
QDMO_pro=dfDMO.iloc[:,1]
SDMO_pro=dfDMO.iloc[:,2]

ord = np.argsort(rHydro_pro)
rHydro_pro_ord =rHydro_pro[ord]
QHydro_pro_ord =QHydro_pro[ord]
SHydro_pro_ord =SHydro_pro[ord]


ordDMO = np.argsort(rDMO_pro)
rDMO_pro_ord =rDMO_pro[ordDMO]
QDMO_pro_ord =QDMO_pro[ordDMO]
SDMO_pro_ord =SDMO_pro[ordDMO]


x=rHydro_pro_ord
y=QHydro_pro_ord

bin_size=0.05

binsQ, averageQ = moving_average(x,y,bin_size)
bins75Q, p75Q   = moving_percentile75(x,y,bin_size)
bins25Q, p25Q   = moving_percentile25(x,y,bin_size)

x=rHydro_pro_ord
z=SHydro_pro_ord
bin_size=0.05

binsS, averageS = moving_average(x,z,bin_size)
bins75S, p75S   = moving_percentile75(x,z,bin_size)
bins25S, p25S   = moving_percentile25(x,z,bin_size)

x=rHydro_pro_ord
z=(1-(QHydro_pro_ord)**2)/(1-(SHydro_pro_ord)**2)
bin_size=0.05

binsT, averageT = moving_average(x,z,bin_size)
bins75T, p75T   = moving_percentile75(x,z,bin_size)
bins25T, p25T   = moving_percentile25(x,z,bin_size)

x=rDMO_pro_ord
y=QDMO_pro_ord

bin_size=0.05

binsQDMO, averageQDMO = moving_average(x,y,bin_size)
bins75QDMO, p75QDMO = moving_percentile75(x,y,bin_size)
bins25QDMO, p25QDMO = moving_percentile25(x,y,bin_size)


x=rDMO_pro_ord
z=SDMO_pro_ord
bin_size=0.05

binsSDMO, averageSDMO = moving_average(x,z,bin_size)
bins75SDMO, p75SDMO = moving_percentile75(x,z,bin_size)
bins25SDMO, p25SDMO = moving_percentile25(x,z,bin_size)

x=rDMO_pro_ord
z=(1-(QDMO_pro_ord)**2)/(1-(SDMO_pro_ord)**2)
bin_size=0.05

binsTDMO, averageTDMO = moving_average(x,z,bin_size)
bins75TDMO, p75TDMO = moving_percentile75(x,z,bin_size)
bins25TDMO, p25TDMO = moving_percentile25(x,z,bin_size)



ax1.plot(binsQ, averageQ, linewidth=5.,color='r' )
ax1.fill_between(binsQ, p75Q, p25Q,facecolor='grey', alpha=0.5,color='r')
ax1.plot(binsQDMO, averageQDMO, linewidth=5.,label='gola',color='k' )
ax1.fill_between(binsQDMO, p75QDMO, p25QDMO,facecolor='grey', alpha=0.5,color='k')

ax2.plot(binsS, averageS, linewidth=5.,color='r')
ax2.fill_between(binsS, p75S, p25S, alpha=0.5,color='r')
ax2.plot(binsSDMO, averageSDMO, linewidth=5.,color='k')
ax2.fill_between(binsSDMO, p75SDMO, p25SDMO, alpha=0.5,color='k')

ax3.plot(binsT, averageT, linewidth=5.,color='r')
ax3.fill_between(binsT, p75T, p25T, alpha=0.5,color='r')
ax3.plot(binsTDMO, averageTDMO, linewidth=5.,color='k')
ax3.fill_between(binsTDMO, p75TDMO, p25TDMO, alpha=0.5,color='k')



empty_patch = mpatches.Patch(color='none', label=r'$10^{11.5-11.}M_{\odot }$') 
ax3.legend(handles=[empty_patch],fontsize=20.)



plt.savefig('/home/pedro/Desktop/Imagenes_Python/Promediados/Formas/PromediadoQSTHydro-DMOM3.pdf', bbox_inches='tight', rasterized=True, dpi=300) ### for publication
